# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

from wordcloud import WordCloud

# %%
mpl.rcParams['font.size']=14

# %%
raw = pd.read_csv( "../data/interim/1.2_lazada_review_cleaner_pure.csv")
raw['review'] = raw['review'].apply(lambda x: x.replace(","," "))

# %%
wordcloud = WordCloud(
                         background_color='white',
                          max_words=200,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(raw['review']))

# %%
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
fig.savefig("../reports/figures/word_cloud.png", dpi=1000)

# %%
train = pd.read_csv( "../data/processed/train_1.csv")
test = pd.read_csv("../data/processed/test_1.csv")
validation = pd.read_csv("../data/processed/validation_1.csv")
