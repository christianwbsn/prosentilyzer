# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

from wordcloud import WordCloud

# %%
mpl.rcParams['font.size']=14

# %%
raw = pd.read_csv( "../data/interim/lazada_review_clean_v2.0_2.csv")
raw['review'] = raw['review'].apply(lambda x: x.replace(","," "))

# %%
wordcloud = WordCloud(
                         background_color='white',
                          max_words=200,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(raw['review']))

# %%
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
fig.savefig("../reports/figures/word_cloud.png", dpi=1000)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f3fd7def390>
