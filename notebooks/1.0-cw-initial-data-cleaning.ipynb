# %% [markdown]
# # Data Cleaning
# ---------------------
# ## Objective
# + Unstructured text data --> normalized word list
# + Extract feature from text data
# ----------------------
# ## Method
# + Number to Words Translation
# + Case to Lower
# + Emoticon to Words Translation
# + Symbol to Words Translation
# + Translate Reduplication
# + Non-Alphanumeric removal
# + Slang and Abbrv Lookup
# + Word Standardization
# + Spell correction
# + Tokenization
# -------------------------------
#
# ### As we can see, our data is *super messy*, so we need to clean it up

# %%
import pandas as pd
import numpy as np
import re
import itertools
import collections
import string
from collections import OrderedDict

# %%
raw = pd.read_csv( "../data/raw/lazada_reviews.csv")

# %%
stop_words = np.array(pd.read_csv("../data/external/stopwords_ID.txt",
                        sep="\n", header=None).values)
neg_words = np.array(pd.read_csv("../data/external/negative_keyword_ID.txt",
                        sep="\n", header=None).values)
pos_words = np.array(pd.read_csv("../data/external/positive_keyword_ID.txt",
                        sep="\n", header=None).values)
slang_words = pd.read_csv("../data/external/kbba_ID.txt",
                        sep="\t", header=None)
root_words = np.array(pd.read_csv("../data/external/rootword_ID.txt",
                        sep="\n", header=None).values)
slang = pd.read_csv("../data/external/slangword_ID.txt",
                        sep=":", header=None)
emoticon = pd.read_csv("../data/external/emoticon.txt",
                        sep="\t", header=None)
booster_words = np.array(pd.read_csv("../data/external/boosterword_ID.txt",
                        sep="\n", header=None).values)
baku_words = pd.read_csv("../data/external/katabaku_ID.txt",
                        sep="|", header=None)
baku_words.columns = [1,0]

# %% [markdown]
# ## Preparing the dict

# %%
slang_words = pd.concat([slang_words, slang, baku_words])
sentiment_words = np.concatenate((pos_words, neg_words, booster_words))
slang_words.drop_duplicates(inplace=True)
emoticon.drop_duplicates(inplace=True)
emoticon = dict(zip(emoticon[0], emoticon[1]))
slang_words = dict(zip(slang_words[0],slang_words[1]))
neg_words = np.unique(neg_words)
pos_words = np.unique(pos_words)
stop_words = np.unique(stop_words)
stop_words = [word for word in stop_words if word not in sentiment_words]

# %%
print("------Dictionary Info---------")
print("Slang words = "  + str(len(slang_words)) + " entries")
print("Emoticon = "  + str(len(emoticon)) + " entries" )
print("Root words = "  + str(len(root_words)) + " entries")
print("Sentiment words = "  + str(len(sentiment_words)) + " entries")
# Out:
# ------Dictionary Info---------
# Slang words = 2294 entries
# Emoticon = 110 entries
# Root words = 27979 entries
# Sentiment words = 8439 entries

# %%
print(raw.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280803 entries, 0 to 280802
# Data columns (total 2 columns):
# rating    280803 non-null int64
# review    220233 non-null object
# dtypes: int64(1), object(1)
# memory usage: 4.3+ MB
# None

# %% [markdown]
# ## There's lot of duplication. Drop it

# %%
raw = raw.dropna(subset=['review'],how='all')
raw = raw.drop_duplicates(subset=['review'])

# %%
print(raw.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19974 entries, 0 to 280801
# Data columns (total 2 columns):
# rating    19974 non-null int64
# review    19974 non-null object
# dtypes: int64(1), object(1)
# memory usage: 468.1+ KB
# None

# %% [markdown]
# ## Prepare the helper

# %%
satuan = ['', 'satu', 'dua', 'tiga', 'empat', 'lima', 'enam', 'tujuh',
          'delapan', 'sembilan', 'sepuluh', 'sebelas']
    
def terbilang_(n):
    if n >= 0 and n <= 11:
        hasil = [satuan[n]]
    elif n >= 12 and n <= 19:
        hasil = terbilang_(n % 10) + ['belas']
    elif n >= 20 and n <= 99:
        hasil = terbilang_(n // 10) + ['puluh'] + terbilang_(n % 10)
    elif n >= 100 and n <= 199:
        hasil = ['seratus'] + terbilang_(n - 100)
    elif n >= 200 and n <= 999:
        hasil = terbilang_(n // 100) + ['ratus'] + terbilang_(n % 100)
    elif n >= 1000 and n <= 1999:
        hasil = ['seribu'] + terbilang_(n - 1000)
    elif n >= 2000 and n <= 999999:
        hasil = terbilang_(n // 1000) + ['ribu'] + terbilang_(n % 1000)
    elif n >= 1000000 and n <= 999999999:
        hasil = terbilang_(n // 1000000) + ['juta'] + terbilang_(n % 1000000)
    else:
        hasil = terbilang_(n // 1000000000) + ['milyar'] + terbilang_(n % 100000000)
    return hasil

def terbilang(n):
    if n == 0:
        return 'nol'
    t = terbilang_(n)
    while '' in t:
        t.remove('')
    return ' '.join(t)

def translate_angka(review):
    number = re.findall("[0-9]+",review)
    for digit in number:
        review = re.sub(digit,terbilang(int(digit))+" ",review)
    return review

# %%
def translate_repeating_words(review):
    repeating_words = re.findall(r'\w*(?:2|")',review)
    for word in repeating_words:
        cleaned = word[:-1]
        review = re.sub(word,cleaned + " " + cleaned, review)
    return review

# %%
def delete_suffix_nya(review):
    return re.sub("(?:nya|ny)[$|\s]"," ",review)

# %%
def translate_emoticon(t):
    for w, v in emoticon.items():
        pattern = re.compile(re.escape(w))
        match = re.search(pattern,t)
        if match:
            t = re.sub(pattern,v,t)
    return t

# %%
def translate_non_alpha_num(t):
    non_alpha_num = {
        '%' : 'persen',
        '$' : 'dolar',
        '@' : 'di',
        '&' : 'dan',
        '/' : 'atau',
        '+' : 'plus'
    }
    for w, v in non_alpha_num.items():
        pattern = re.compile(re.escape(w))
        match = re.search(pattern,t)
        if match:
            t = re.sub(pattern,v + " ",t)
    return t

# %%
def remove_non_alphanumeric(review):
    return re.sub("[^a-zA-Z\d]"," ", review)

# %%
def normalizing_words(review):
    return ''.join(''.join(s)[:1] for _, s in itertools.groupby(review))

# %% [markdown]
# ## Applying Changes. Do it sequentially. Order matters

# %%
raw['review'] = raw['review'].apply(translate_repeating_words)
raw.head()
# Out:
#    rating                                             review
# 0       1  pengiriman melalui NINJA sangattttt lamaaaa. j...
# 1       1  pesananku pada no order ini terkirim dgn baik....
# 2       5  ga sia sia susah payah ikutan flashsale akhirn...
# 3       5  Setelah 7 kali gagal flashsale, akhirnya dapat...
# 4       5  saya kurang setuju dengan FS, memang sih untuk...

# %%
raw['review'] = raw['review'].apply(translate_emoticon)
raw.head()
# Out:
#    rating                                             review
# 0       1  pengiriman melalui NINJA sangattttt lamaaaa. j...
# 1       1  pesananku pada no order ini terkirim dgn baik....
# 2       5  ga sia sia susah payah ikutan flashsale akhirn...
# 3       5  Setelah 7 kali gagal flashsale, akhirnya dapat...
# 4       5  saya kurang setuju dengan FS, memang sih untuk...

# %%
raw['review'] = raw['review'].apply(lambda x: x.lower())
raw.head()
# Out:
#    rating                                             review
# 0       1  pengiriman melalui ninja sangattttt lamaaaa. j...
# 1       1  pesananku pada no order ini terkirim dgn baik....
# 2       5  ga sia sia susah payah ikutan flashsale akhirn...
# 3       5  setelah 7 kali gagal flashsale, akhirnya dapat...
# 4       5  saya kurang setuju dengan fs, memang sih untuk...

# %%
raw['review'] = raw['review'].apply(translate_non_alpha_num)
raw.head()
# Out:
#    rating                                             review
# 0       1  pengiriman melalui ninja sangattttt lamaaaa. j...
# 1       1  pesananku pada no order ini terkirim dgn baik....
# 2       5  ga sia sia susah payah ikutan flashsale akhirn...
# 3       5  setelah 7 kali gagal flashsale, akhirnya dapat...
# 4       5  saya kurang setuju dengan fs, memang sih untuk...

# %%
raw['review'] = raw['review'].apply(remove_non_alphanumeric)
raw.head()
# Out:
#    rating                                             review
# 0       1  pengiriman melalui ninja sangattttt lamaaaa  j...
# 1       1  pesananku pada no order ini terkirim dgn baik ...
# 2       5  ga sia sia susah payah ikutan flashsale akhirn...
# 3       5  setelah 7 kali gagal flashsale  akhirnya dapat...
# 4       5  saya kurang setuju dengan fs  memang sih untuk...

# %%
raw['review'] = raw['review'].apply(delete_suffix_nya)
raw['review']
# Out:
# 0         pengiriman melalui ninja sangattttt lamaaaa  j...
# 1         pesananku pada no order ini terkirim dgn baik ...
# 2         ga sia sia susah payah ikutan flashsale akhir ...
# 3         setelah 7 kali gagal flashsale  akhir dapat ju...
# 4         saya kurang setuju dengan fs  memang sih untuk...
# 5         kurir ninja express leleeeeetttt kecewa   kena...
# 6         pengiriman ke kota depok membutuhkan 11 hari t...
# 7         barang udah nyampe   cuma lama banget mending ...
# 8         saran tolong pengitiman paket saya jng melalui...
# 9         hp xiomi emng ok  cepat nyampe kurir ramah  te...
# 10        beli flash sale xiaomi redmi 5a plus powerbank...
# 11        barang sudah sampai secara cepat dan tepat  tp...
# 12        proses waktu pengiriman setelah pemesanan sang...
# 13        barang bagus banget garansi tam dikirim jam 1 ...
# 14        bulan lalu dpet redmi 5 plus gold dan item  sk...
# 15        lazadaa ituuu kadangh lamaa pengiriman kadang ...
# 16        ini pertama kali dapet flash sale barang sampa...
# 17        pengiriman cepat  kurir ramah  lazada paling t...
# 18        bismillah   walkhamdulillah barang telah diter...
# 19        flash sale terbaik     pesan kemarin  hari ini...
# 20        mohon lain kali ke depan jangan ha bergantung ...
# 21        hari minggu mas kurir tetep nganterin barang  ...
# 22        waktu fles sel dpt 3pcs cuma yang diacc ha 1 p...
# 23        meskipun tadi kurir minta maaf  tapi memang su...
# 24        jual seharga 1 199 bundling dgn hands free tap...
# 25        jadi saya bingung harus balikin dana atao jd v...
# 26        sebanyak 10 unit hp xiomie redmi 5a yg saya da...
# 27        terimakasih  berkat lazada saya bisa menabung ...
# 28        udah kesekian kali ikut flash sale   alhamduli...
# 29        barang sampai dengan aman  meskipun sistem cod...
#                                 ...
# 280751    packing alakadar  barang kualitas standar sesu...
# 280752          kualitas barang tidak sesuai dengan harapan
# 280753    barang udah sampai   packing rapi    bhan luma...
# 280757                                  puas dgn produk nya
# 280760    dompet ok and murah lagi  thank s lazada dan s...
# 280762    bagus untuk harga segitu tapi posisi tempat ka...
# 280764                                          bagus sesua
# 280765    barang bagus sesuai harga tapi tolong dong aga...
# 280766               bagus saya suka    cuma kurir ga sopan
# 280767                                sesuailah dgn harga
# 280770    namun kebanyakan ini dompet type cewe bkan cow...
# 280771                             recomen dan cepat sampai
# 280773    real pict  barang bagus  kiriman sesuai estima...
# 280776    tampak depan bagus  tapi cardholder  agak beda...
# 280777      barang sudah sampai dan sesuai deskripsi produk
# 280778                                       puasss pokonya
# 280779    sesuai gambar  bahan bagus  harga  standar tap...
# 280780    bagus  halus dan sesuai gambar  good garuda sh...
# 280781    barang sudah sampai dan diterima dengan baik k...
# 280782    kualitas barang yg terima bagus  tetapi utk di...
# 280783    barang  bagus  cuma sedikit jelek jahitan  kur...
# 280784                         sesuai dengan pesanan  trims
# 280786    datang  cepat buanget  recommended seller suks...
# 280787    bagus jahitan rapi tapi kalok buat cowok kebes...
# 280791                                baguussss bangeettttt
# 280793    tdk sesuai gambar beda sekali brng yg di kirim...
# 280797                   dompet  tebel  sesuai sama di foto
# 280798            barang sudah di terima bagus   txs lazada
# 280800            barangy lumayan bagus sesuai dengan harga
# 280801    mayan sesuai dgn gambar   paking rapi    jempo...
# Name: review, Length: 19974, dtype: object

# %%
raw['review'] = raw['review'].apply(translate_angka)
raw.head()
# Out:
#    rating                                             review
# 0       1  pengiriman melalui ninja sangattttt lamaaaa  j...
# 1       1  pesananku pada no order ini terkirim dgn baik ...
# 2       5  ga sia sia susah payah ikutan flashsale akhir ...
# 3       5  setelah tujuh  kali gagal flashsale  akhir dap...
# 4       5  saya kurang setuju dengan fs  memang sih untuk...

# %%
raw['review'] = raw['review'].apply(normalizing_words)
raw.head()
# Out:
#    rating                                             review
# 0       1  pengiriman melalui ninja sangat lama jauh berb...
# 1       1  pesananku pada no order ini terkirim dgn baik ...
# 2       5  ga sia sia susah payah ikutan flashsale akhir ...
# 3       5  setelah tujuh kali gagal flashsale akhir dapat...
# 4       5  saya kurang setuju dengan fs memang sih untuk ...

# %%
raw['review'] = raw['review'].apply(lambda x: x.split())
raw['review'] = raw['review'].apply(lambda x: np.array(x))
def mapping_slang_words(review):
    return [slang_words[word] if word in slang_words else word for word in review]
raw['review'] = raw['review'].apply(mapping_slang_words)
raw.head()
# Out:
#    rating                                             review
# 0       1  [pengiriman, melalui, ninja, sangat, lama, jau...
# 1       1  [pesananku, pada, nomor, order, ini, terkirim,...
# 2       5  [tidak, sia, sia, susah, payah, ikutan, flash ...
# 3       5  [setelah, tujuh, kali, gagal, flash sale, akhi...
# 4       5  [saya, kurang, setuju, dengan, flash sale, mem...

# %% [markdown]
# ## Norvig Spell-checking Algorithm

# %%
class spellCheck:
    def train(self,features):
        model = collections.defaultdict(lambda:1)
        for f in features:
            model[f] += 1
        return model
    
    def __init__(self):
        self.NWORDS = self.train(self.words(open('../data/external/spellingset_ID.txt').read()))
        self.alphabet = 'abcdefghijklmnopqrstuvwxyz'
    
    def words(self,text):
        return re.findall('[a-z]+', text.lower())
    
    def edits1(self, word):
        splits     = [(word[:i], word[i:]) for i in range(len(word) + 1)]
        deletes    = [a + b[1:] for a, b in splits if b]
        transposes = [a + b[1] + b[0] + b[2:] for a, b in splits if len(b)>1]
        replaces   = [a + c + b[1:] for a, b in splits for c in self.alphabet if b]
        inserts    = [a + c + b     for a, b in splits for c in self.alphabet]
        return set(deletes + transposes + replaces + inserts)
    
    def known_edits2(self, word):
        return set(e2 for e1 in self.edits1(word) for e2 in self.edits1(e1) if e2 in self.NWORDS)

    def known(self,words): return set(w for w in words if w in self.NWORDS)

    def correct(self, word):
        candidates = self.known([word]) or self.known(self.edits1(word)) or self.known_edits2(word) or [word]
        return max(candidates, key=self.NWORDS.get)

def correctSpelling(text):
    sc = spellCheck()
    return sc.correct(text) if text not in root_words else text

# %%
def spelling_correction(word_list):
    transformed = []
    for word in word_list:
        transformed.append(correctSpelling(word))
    return np.array(transformed)

# %%
raw['review'] = raw['review'].apply(spelling_correction)

# %%
raw = raw.dropna(subset=['review'],how='all')
raw = raw[raw['review'].map(len) > 0]
def avg_word(words):
  return (sum(len(word) for word in words)/len(words))

raw['avg_word'] = raw['review'].apply(lambda x: avg_word(x))
raw['word_count'] = raw['review'].map(len)

# %%
raw
# Out:
#         rating                                             review  avg_word  \
# 0            1  [pengiriman, melalui, ninja, sangat, lama, jau...  5.571429
# 1            1  [pesananku, pada, nomor, order, ini, terkirim,...  5.193878
# 2            5  [tidak, sia, sia, susah, payah, ikutan, flash ...  5.888889
# 3            5  [setelah, tujuh, kali, gagal, flash sale, akhi...  5.962963
# 4            5  [saya, kurang, setuju, dengan, flash sale, mem...  5.620690
# 5            1  [kurir, ninja, express, lambat, kecewa, kenapa...  5.125000
# 6            1  [pengiriman, ke, kota, depak, membutuhkan, seb...  5.747899
# 7            5  [barang, sudah, sampai, hanya, lama, sekali, l...  5.571429
# 8            5  [saran, tolong, pengiriman, paket, saya, jeng,...  5.733333
# 9            5  [telepon genggam, xiaomi, memang, oke, cepat, ...  5.631579
# 10           1  [beli, flash, sale, xiaomi, redmi, lima, a, pl...  5.700000
# 11           1  [barang, sudah, sampai, secara, cepat, dan, te...  5.200000
# 12           5  [proses, waktu, pengiriman, setelah, pesanan, ...  5.464286
# 13           1  [barang, bagus, sekali, garansi, tam, dikirim,...  5.368421
# 14           5  [bulan, lalu, dapet, redmi, lima, plus, emas, ...  4.428571
# 15           1  [lazada, itu, kadang, lama, pengiriman, kadang...  5.400000
# 16           4  [ini, pertama, kali, dapat, flash, sale, baran...  5.571429
# 17           5  [pengiriman, cepat, kurir, ramah, lazada, pali...  6.066667
# 18           5  [bismillah, alhamdulilah, barang, telah, diter...  6.105263
# 19           5  [flash, sale, terbaik, pesan, kemarin, hari, i...  6.538462
# 20           5  [mohon, lain, kali, ke, depan, jangan, tertawa...  5.500000
# 21           4  [hari, minggu, mas, kurir, tetap, nganterin, b...  5.733333
# 22           5  [waktu, flash, sale, dapat, tiga, buah, hanya,...  5.823529
# 23           5  [meskipun, tadi, kurir, minta, mau, tapi, mema...  5.586207
# 24           5  [jual, secara, satu, satu, i, banding, dengan,...  5.600000
# 25           3  [jadi, saya, bingung, harus, kembalikan, dana,...  5.120000
# 26           4  [sebanyak, sepuluh, unit, telepon genggam, xia...  5.568182
# 27           5  [terima kasih, berkat, lazada, saya, bisa, men...  6.206897
# 28           1  [sudah, kesekian, kali, ikut, flash, sale, alh...  6.176471
# 29           1  [barang, sampai, dengan, aman, meskipun, siste...  5.929577
# ...        ...                                                ...       ...
# 280751       1  [penjelasan, seadanya, barang, kualitas, stand...  7.444444
# 280752       1  [kualitas, barang, tidak, sesuai, dengan, hara...  6.333333
# 280753       3  [barang, sudah, sampai, penjelasan, rapi, han,...  5.545455
# 280757       2                        [puas, dengan, produk, nya]  4.750000
# 280760       3  [dompet, oke, dan, murah, lagi, terima kasih, ...  4.900000
# 280762       3  [bagus, untuk, harga, begitu, tapi, posisi, te...  5.272727
# 280764       1                                     [bagus, semua]  5.000000
# 280765       1  [barang, bagus, sesuai, harga, tapi, tolong, d...  5.200000
# 280766       3    [bagus, saya, suka, hanya, kurir, tidak, sopan]  4.714286
# 280767       3                         [sesuailah, dengan, harga]  6.666667
# 280770       3  [namun, kebanyakan, ini, dompet, tipe, cewek, ...  5.214286
# 280771       1             [direkomendasikan, dan, cepat, sampai]  7.500000
# 280773       2  [memang, gambar, barang, bagus, kiriman, sesua...  7.000000
# 280776       3  [tampak, depan, bagus, tapi, cardholder, agak,...  5.571429
# 280777       3  [barang, sudah, sampai, dan, sesuai, deskripsi...  5.857143
# 280778       2                                   [puas, pokoknya]  6.000000
# 280779       2  [sesuai, gambar, bahan, bagus, harga, standar,...  5.615385
# 280780       2  [bagus, halus, dan, sesuai, gambar, bagus, gar...  5.800000
# 280781       1  [barang, sudah, sampai, dan, diterima, dengan,...  5.727273
# 280782       3  [kualitas, barang, yang, terima, bagus, tetapi...  5.636364
# 280783       3  [barang, bagus, hanya, sedikit, jelek, jadian,...  5.500000
# 280784       3            [sesuai, dengan, pesanan, terima kasih]  7.750000
# 280786       3  [datang, cepat, banget, direkomendasikan, sele...  7.125000
# 280787       3  [bagus, jadian, rapi, tapi, kalau, buat, cowok...  5.000000
# 280791       1                                    [bagus, sekali]  5.500000
# 280793       3  [tidak, sesuai, gambar, beda, sekali, barang, ...  4.653846
# 280797       2            [dompet, tebal, sesuai, sama, di, foto]  4.500000
# 280798       3  [barang, sudah, di, terima, bagus, terima kasi...  6.000000
# 280800       3    [barang, lumayan, bagus, sesuai, dengan, harga]  5.833333
# 280801       3  [lumayan, sesuai, dengan, gambar, penjelasan, ...  5.666667
#
#         word_count
# 0               21
# 1               98
# 2               27
# 3               27
# 4               58
# 5               16
# 6              119
# 7               21
# 8               15
# 9               19
# 10              20
# 11              20
# 12              28
# 13              19
# 14              21
# 15              15
# 16              21
# 17              15
# 18              19
# 19              13
# 20              34
# 21              30
# 22              34
# 23              29
# 24              20
# 25              25
# 26              44
# 27              29
# 28              17
# 29              71
# ...            ...
# 280751           9
# 280752           6
# 280753          11
# 280757           4
# 280760          10
# 280762          11
# 280764           2
# 280765          15
# 280766           7
# 280767           3
# 280770          14
# 280771           4
# 280773           8
# 280776          14
# 280777           7
# 280778           2
# 280779          13
# 280780          10
# 280781          11
# 280782          22
# 280783           8
# 280784           4
# 280786           8
# 280787          16
# 280791           2
# 280793          26
# 280797           6
# 280798           7
# 280800           6
# 280801           9
#
# [19940 rows x 4 columns]

# %%
raw.to_csv("../data/interim/1.0_lazada_review_clean_without_stop_removal.csv", index=False)

# %% [markdown]
# ## Traditional Stop Words Removal (Optional)
# This preprocessing step still debatable to be used because using generic list of stopwords can have a negative impact on sentiment analysis performance. Stop words removed can contain information that might be important for the sentiment analysis.

# %%
def remove_stop_words(word_list):
    return [word for word in word_list if word not in stop_words]
raw['review'] = raw['review'].apply(remove_stop_words)
raw.head()
# Out:
#    rating                                             review  avg_word  \
# 0       1  [pengiriman, ninja, sangat, lama, jauh, berbed...  5.571429
# 1       1  [pesananku, nomor, order, terkirim, baik, nomo...  5.193878
# 2       5  [tidak, sia, sia, susah, payah, ikutan, flash ...  5.888889
# 3       5  [tujuh, kali, gagal, flash sale, padahal, tida...  5.962963
# 4       5  [kurang, setuju, flash sale, sih, strategi, pe...  5.620690
#
#    word_count
# 0          21
# 1          98
# 2          27
# 3          27
# 4          58

# %%
raw = raw.dropna(subset=['review'],how='all')
raw = raw[raw['review'].map(len) > 0]
def avg_word(words):
  return (sum(len(word) for word in words)/len(words))

raw['avg_word'] = raw['review'].apply(lambda x: avg_word(x))
raw['word_count'] = raw['review'].map(len)

# %%
raw.to_csv("../data/interim/1.0_lazada_review_clean_with_stop_removal.csv", index=False)
