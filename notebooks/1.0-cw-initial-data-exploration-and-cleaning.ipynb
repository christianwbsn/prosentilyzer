# %%
import pandas as pd
import numpy as np
import re
import itertools
import collections
import string
from collections import OrderedDict

# %%
raw = pd.read_csv( "../data/raw/lazada_reviews.csv")
stop_words = np.array(pd.read_csv("../data/external/stopwords_ID.txt",
                        sep="\n", header=None).values)
neg_words = np.array(pd.read_csv("../data/external/negative_keyword_ID.txt",
                        sep="\n", header=None).values)
pos_words = np.array(pd.read_csv("../data/external/positive_keyword_ID.txt",
                        sep="\n", header=None).values)
slang_words = pd.read_csv("../data/external/kbba_ID.txt",
                        sep="\t", header=None)
root_words = np.array(pd.read_csv("../data/external/rootword_ID.txt",
                        sep="\n", header=None).values)
slang = pd.read_csv("../data/external/slangword_ID.txt",
                        sep=":", header=None)
slang_words = pd.concat([slang_words, slang])
sentiment_words = np.concatenate((pos_words, neg_words))

# %%
slang_words.drop_duplicates(inplace=True)
slang_words = dict(zip(slang_words[0],slang_words[1]))
neg_words = np.unique(neg_words)
pos_words = np.unique(pos_words)
stop_words = np.unique(stop_words)
stop_words = [word for word in stop_words if word not in sentiment_words]

# %%
print(raw.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280803 entries, 0 to 280802
# Data columns (total 2 columns):
# rating    280803 non-null int64
# review    220233 non-null object
# dtypes: int64(1), object(1)
# memory usage: 4.3+ MB
# None

# %%
raw = raw.dropna(subset=['review'],how='all')
raw = raw.drop_duplicates(subset=['review'])

# %%
print(raw.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19974 entries, 0 to 280801
# Data columns (total 2 columns):
# rating    19974 non-null int64
# review    19974 non-null object
# dtypes: int64(1), object(1)
# memory usage: 468.1+ KB
# None

# %%
raw.head()
# Out:
#    rating                                             review
# 0       1  pengiriman melalui NINJA sangattttt lamaaaa. j...
# 1       1  pesananku pada no order ini terkirim dgn baik....
# 2       5  ga sia sia susah payah ikutan flashsale akhirn...
# 3       5  Setelah 7 kali gagal flashsale, akhirnya dapat...
# 4       5  saya kurang setuju dengan FS, memang sih untuk...

# %%
satuan = ['', 'satu', 'dua', 'tiga', 'empat', 'lima', 'enam', 'tujuh',
          'delapan', 'sembilan', 'sepuluh', 'sebelas']
    
def terbilang_(n):
    if n >= 0 and n <= 11:
        hasil = [satuan[n]]
    elif n >= 12 and n <= 19:
        hasil = terbilang_(n % 10) + ['belas']
    elif n >= 20 and n <= 99:
        hasil = terbilang_(n // 10) + ['puluh'] + terbilang_(n % 10)
    elif n >= 100 and n <= 199:
        hasil = ['seratus'] + terbilang_(n - 100)
    elif n >= 200 and n <= 999:
        hasil = terbilang_(n // 100) + ['ratus'] + terbilang_(n % 100)
    elif n >= 1000 and n <= 1999:
        hasil = ['seribu'] + terbilang_(n - 1000)
    elif n >= 2000 and n <= 999999:
        hasil = terbilang_(n // 1000) + ['ribu'] + terbilang_(n % 1000)
    elif n >= 1000000 and n <= 999999999:
        hasil = terbilang_(n // 1000000) + ['juta'] + terbilang_(n % 1000000)
    else:
        hasil = terbilang_(n // 1000000000) + ['milyar'] + terbilang_(n % 100000000)
    return hasil

def terbilang(n):
    if n == 0:
        return 'nol'
    t = terbilang_(n)
    while '' in t:
        t.remove('')
    return ' '.join(t)

def translate_angka(review):
    number = re.findall("[0-9]+",review)
    for digit in number:
        review = re.sub(digit,terbilang(int(digit)),review)
    return review

# %%
def translate_repeating_words(review):
    rev = re.sub("(?:2|\")"," " + review,review)
    return re.sub("(?:2|\")","",rev)

# %%
raw['review'] = raw['review'].apply(lambda x: x.lower())
raw['review'] = raw['review'].apply(translate_repeating_words)
raw['review'] = raw['review'].apply(translate_angka)

# %%
def remove_non_letter(review):
    return re.sub("[^a-zA-Z]"," ", review)
                  
raw['review'] = raw['review'].apply(remove_non_letter)
raw.head()
# Out:
#    rating                                             review
# 0       1  pengiriman melalui ninja sangattttt lamaaaa  j...
# 1       1  pesananku pada no order ini terkirim dgn baik ...
# 2       5  ga sia sia susah payah ikutan flashsale akhirn...
# 3       5  setelah tujuh kali gagal flashsale  akhirnya d...
# 4       5  saya kurang setuju dengan fs  memang sih untuk...

# %%
def normalizing_words(review):
    return ''.join(''.join(s)[:1] for _, s in itertools.groupby(review))
raw['review'] = raw['review'].apply(normalizing_words)
raw.head()
# Out:
#    rating                                             review
# 0       1  pengiriman melalui ninja sangat lama jauh berb...
# 1       1  pesananku pada no order ini terkirim dgn baik ...
# 2       5  ga sia sia susah payah ikutan flashsale akhirn...
# 3       5  setelah tujuh kali gagal flashsale akhirnya da...
# 4       5  saya kurang setuju dengan fs memang sih untuk ...

# %%
class spellCheck:
    def train(self,features):
        model = collections.defaultdict(lambda:1)
        for f in features:
            model[f] += 1
        return model
    
    def __init__(self):
        self.NWORDS = self.train(self.words(open('../data/external/spellingset_ID.txt').read()))
        self.alphabet = 'abcdefghijklmnopqrstuvwxyz'
    
    def words(self,text):
        return re.findall('[a-z]+', text.lower())
    
    def edits1(self, word):
        splits     = [(word[:i], word[i:]) for i in range(len(word) + 1)]
        deletes    = [a + b[1:] for a, b in splits if b]
        transposes = [a + b[1] + b[0] + b[2:] for a, b in splits if len(b)>1]
        replaces   = [a + c + b[1:] for a, b in splits for c in self.alphabet if b]
        inserts    = [a + c + b     for a, b in splits for c in self.alphabet]
        return set(deletes + transposes + replaces + inserts)
    
    def known_edits2(self, word):
        return set(e2 for e1 in self.edits1(word) for e2 in self.edits1(e1) if e2 in self.NWORDS)

    def known(self,words): return set(w for w in words if w in self.NWORDS)

    def correct(self, word):
        candidates = self.known([word]) or self.known(self.edits1(word)) or self.known_edits2(word) or [word]
        return max(candidates, key=self.NWORDS.get)

def correctSpelling(text):
    sc = spellCheck()
    return sc.correct(text) if text not in root_words else text

raw['review'] = raw['review'].apply(lambda x: x.split())

# %%
raw['review'] = raw['review'].apply(lambda x: np.array(x))
def mapping_slang_words(review):
    return [slang_words[word] if word in slang_words else word for word in review]
raw['review'] = raw['review'].apply(mapping_slang_words)

# %%
def spelling_correction(word_list):
    transformed = []
    for word in word_list:
        transformed.append(correctSpelling(word))
    return np.array(transformed)

# %%
raw['review'] = raw['review'].apply(spelling_correction)

# %%
def remove_stop_words(word_list):
    return [word for word in word_list if word not in stop_words]
raw['review'] = raw['review'].apply(remove_stop_words)
raw.head()
# Out:
#    rating                                             review
# 0       1  [pengiriman, ninja, sangat, lama, jauh, berbed...
# 1       1  [pesananku, nomor, order, terkirim, baik, nomo...
# 2       5  [tidak, sia, sia, susah, payah, ikutan, flashs...
# 3       5  [tujuh, kali, gagal, flashsale, padahal, nga, ...
# 4       5  [kurang, setuju, flash sale, sih, strategi, ma...

# %%
raw = raw.dropna(subset=['review'],how='all')
raw = raw[raw['review'].map(len) > 0]
def avg_word(words):
  return (sum(len(word) for word in words)/len(words))

raw['avg_word'] = raw['review'].apply(lambda x: avg_word(x))
raw['word_count'] = raw['review'].map(len)

# %%
raw
# Out:
#         rating                                             review  avg_word  \
# 0            1  [pengiriman, ninja, sangat, lama, jauh, berbed...  5.812500
# 1            1  [pesananku, nomor, order, terkirim, baik, nomo...  6.152985
# 2            5  [tidak, sia, sia, susah, payah, ikutan, flashs...  6.105263
# 3            5  [tujuh, kali, gagal, flashsale, padahal, nga, ...  6.125000
# 4            5  [kurang, setuju, flash sale, sih, strategi, ma...  6.678571
# 5            1  [kurir, ninja, express, lambat, kecewa, sih, l...  5.500000
# 6            1  [pengiriman, kota, depak, membutuhkan, sebelas...  6.689189
# 7            5  [barang, cuma, lama, lebih baik, pakai, eksped...  5.400000
# 8            5  [saran, tolong, pengiriman, paket, jeng, jasa,...  5.909091
# 9            5  [telepon genggam, xiaomi, oke, cepat, kurir, r...  5.800000
# 10           1  [beli, flash, sale, xiaomi, redmi, powerbank, ...  5.833333
# 11           1  [barangnya, cepat, tepat, sayang, pesan, baran...  5.444444
# 12           5  [proses, pengiriman, pesanan, sangat, cepat, k...  5.473684
# 13           1  [barang, bagus, garansi, tam, dikirim, jam, ba...  5.500000
# 14           5  [dapet, redmi, plus, emas, hitam, pagi, redmi,...  4.909091
# 15           1  [lazada, kadang, lama, mengiriminya, kadang, c...  5.916667
# 16           4  [kali, flash, sale, barang, aman, rapi, pengir...  5.333333
# 17           5  [pengiriman, cepat, kurir, ramah, lazada, top,...  6.076923
# 18           5  [bismillah, alhamdulilah, barang, diterima, ba...  6.818182
# 19           5  [flash, sale, terbaik, pesan, kemarin, langsun...  6.727273
# 20           5  [mohon, kali, depannya, hanya, bergantung, age...  6.789474
# 21           4  [minggu, mas, kurir, tetap, nganterin, barang,...  5.636364
# 22           5  [flash, sale, tigapcs, cuma, hanya, buah, sang...  6.894737
# 23           5  [kulitnya, tugasnya, mengantarkan, barang, pel...  7.500000
# 24           5  [jualnya, jualnya, satusembilan, puluh, sembil...  7.400000
# 25           3  [bingung, balikin, dana, rocker, balikin, dana...  5.600000
# 26           4  [sepuluh, unit, telepon genggam, xiaomi, redmi...  6.666667
# 27           5  [terimakasih, berkat, lazada, bisa, mendung, b...  7.055556
# 28           1  [kesekian, kali, flash, sale, alhamdulilah, ba...  6.900000
# 29           1  [barang, aman, sistem, cash on delivery, butuh...  6.731707
# ...        ...                                                ...       ...
# 280751       1  [alakadarnya, barang, kualitas, standar, sesua...  7.500000
# 280752       1         [kualitas, barang, tidak, sesuai, harapan]  6.400000
# 280753       3         [barang, rapi, han, lumayan, foto, makash]  5.000000
# 280757       2                                     [puas, produk]  5.000000
# 280760       3  [dompetnya, oke, an, murah, thank, s, lazada, ...  4.625000
# 280762       3        [bagus, harga, posisi, kartu, beda, gambar]  5.166667
# 280764       1                                            [bagus]  5.000000
# 280765       1  [barang, bagus, sesuai, harga, tolong, kuat, s...  6.222222
# 280766       3        [bagus, suka, cuma, kulitnya, tidak, sopan]  5.166667
# 280767       3                                 [sesuailah, harga]  7.000000
# 280770       3  [kebanyakan, dompet, tipe, cewek, cowo, meetin...  6.125000
# 280771       1                                   [secemen, cepat]  6.000000
# 280773       2  [real, pit, barang, bagus, kiriman, sesuai, es...  6.250000
# 280776       3   [tampak, bagus, cardholder, beda, gambar, bagus]  6.000000
# 280777       3                [barang, sesuai, deskripsi, produk]  6.750000
# 280778       2                                   [puas, pokoknya]  6.000000
# 280779       2  [sesuai, gambar, bahunya, bagus, harga, standa...  6.090909
# 280780       2  [bagus, halus, sesuai, gambar, bagus, garuda, ...  6.111111
# 280781       1     [barang, diterima, baik, kok, ongkirnya, amat]  5.666667
# 280782       3  [kualitas, barang, terima, bagus, dipakai, men...  6.000000
# 280783       3  [barang, bagus, cuma, sedikit, jelek, jadian, ...  5.375000
# 280784       3                    [sesuai, pesanan, terima kasih]  8.333333
# 280786       3  [cepat, banget, rekomendasi, selera, sukses, l...  6.666667
# 280787       3  [bagus, jadian, rapi, kalo, cowok, kebesaran, ...  5.600000
# 280791       1                                            [bagus]  5.000000
# 280793       3  [tidak, sesuai, gambar, beda, barang, kirim, g...  4.937500
# 280797       2                      [dompet, tebal, sesuai, foto]  5.250000
# 280798       3               [barang, terima, bagus, tas, lazada]  5.200000
# 280800       3            [barang, lumayan, bagus, sesuai, harga]  5.800000
# 280801       3  [lumayan, sesuai, gambar, rapi, lumayan, sesua...  5.800000
#
#         word_count
# 0               16
# 1              268
# 2               19
# 3               16
# 4               28
# 5               10
# 6               74
# 7               15
# 8               11
# 9               15
# 10              12
# 11              18
# 12              38
# 13              28
# 14              11
# 15              12
# 16              12
# 17              13
# 18              11
# 19              11
# 20              38
# 21              22
# 22              19
# 23              12
# 24              20
# 25              25
# 26              18
# 27              18
# 28              10
# 29              82
# ...            ...
# 280751           8
# 280752           5
# 280753           6
# 280757           2
# 280760           8
# 280762           6
# 280764           1
# 280765           9
# 280766           6
# 280767           2
# 280770           8
# 280771           2
# 280773           8
# 280776           6
# 280777           4
# 280778           2
# 280779          11
# 280780           9
# 280781           6
# 280782          16
# 280783           8
# 280784           3
# 280786           6
# 280787          10
# 280791           1
# 280793          16
# 280797           4
# 280798           5
# 280800           5
# 280801          10
#
# [19872 rows x 4 columns]

# %%
raw.to_csv("../data/interim/lazada_review_clean_1.csv", index=False)
