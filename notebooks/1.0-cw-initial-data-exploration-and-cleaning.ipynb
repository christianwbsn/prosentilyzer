# %%
import pandas as pd
import numpy as np
import re
import itertools
import collections
from collections import OrderedDict

# %%
raw = pd.read_csv( "../data/raw/lazada_reviews.csv")
stop_words = np.array(pd.read_csv("../data/external/stopwords_ID.txt",
                        sep="\n", header=None).values)
neg_words = np.array(pd.read_csv("../data/external/negative_keyword_ID.txt",
                        sep="\n", header=None).values)
pos_words = np.array(pd.read_csv("../data/external/positive_keyword_ID.txt",
                        sep="\n", header=None).values)
slang_words = pd.read_csv("../data/external/kbba_ID.txt",
                        sep="\t", header=None)
root_words = np.array(pd.read_csv("../data/external/rootword_ID.txt",
                        sep="\n", header=None).values)
slang = pd.read_csv("../data/external/slangword_ID.txt",
                        sep=":", header=None)
slang_words = pd.concat([slang_words,slang])

# %%
slang_words.drop_duplicates(inplace=True)
slang_words = dict(zip(slang_words[0],slang_words[1]))
neg_words = np.unique(neg_words)
pos_words = np.unique(pos_words)
stop_words = np.unique(stop_words)

# %%
print(raw.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280803 entries, 0 to 280802
# Data columns (total 2 columns):
# rating    280803 non-null int64
# review    220233 non-null object
# dtypes: int64(1), object(1)
# memory usage: 4.3+ MB
# None

# %%
raw = raw.dropna(subset=['review'],how='all')
raw = raw.drop_duplicates(subset=['review'])

# %%
print(raw.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19974 entries, 0 to 280801
# Data columns (total 2 columns):
# rating    19974 non-null int64
# review    19974 non-null object
# dtypes: int64(1), object(1)
# memory usage: 468.1+ KB
# None

# %%
raw.head()
# Out:
#    rating                                             review
# 0       1  pengiriman melalui NINJA sangattttt lamaaaa. j...
# 1       1  pesananku pada no order ini terkirim dgn baik....
# 2       5  ga sia sia susah payah ikutan flashsale akhirn...
# 3       5  Setelah 7 kali gagal flashsale, akhirnya dapat...
# 4       5  saya kurang setuju dengan FS, memang sih untuk...

# %%
def remove_non_letter(review):
    return re.sub("[^a-zA-Z]"," ", review
                  
raw['review'] = raw['review'].apply(lambda x: x.lower())
raw['review'] = raw['review'].apply(remove_non_letter)

# %%
def normalizing_words(review):
    return ''.join(''.join(s)[:1] for _, s in itertools.groupby(review))
raw['review'] = raw['review'].apply(normalizing_words)

# %%
class spellCheck:
    def train(self,features):
        model = collections.defaultdict(lambda:1)
        for f in features:
            model[f] += 1
        return model
    
    def __init__(self):
        self.NWORDS = self.train(self.words(open('../data/external/spellingset_ID.txt').read()))
        self.alphabet = 'abcdefghijklmnopqrstuvwxyz'
    
    def words(self,text):
        return re.findall('[a-z]+', text.lower())
    
    def edits1(self, word):
        splits     = [(word[:i], word[i:]) for i in range(len(word) + 1)]
        deletes    = [a + b[1:] for a, b in splits if b]
        transposes = [a + b[1] + b[0] + b[2:] for a, b in splits if len(b)>1]
        replaces   = [a + c + b[1:] for a, b in splits for c in self.alphabet if b]
        inserts    = [a + c + b     for a, b in splits for c in self.alphabet]
        return set(deletes + transposes + replaces + inserts)
    
    def known_edits2(self, word):
        return set(e2 for e1 in self.edits1(word) for e2 in self.edits1(e1) if e2 in self.NWORDS)

    def known(self,words): return set(w for w in words if w in self.NWORDS)

    def correct(self, word):
        candidates = self.known([word]) or self.known(self.edits1(word)) or self.known_edits2(word) or [word]
        return max(candidates, key=self.NWORDS.get)

def correctSpelling(text):
    sc = spellCheck()
    return sc.correct(text) if text not in root_words else text

raw['review'] = raw['review'].apply(lambda x: x.split())

# %%
def spelling_correction(word_list):
    transformed = []
    for word in word_list:
        transformed.append(correctSpelling(word))
    return transformed

# %%
raw['review'] = raw['review'].apply(spelling_correction)

# %%
def mapping_slang_words(review):
    return [slang_words[word] if word in slang_words else word for word in review]
raw['review'] = raw['review'].apply(mapping_slang_words)

# %%
def remove_stop_words(word_list):
    return [word for word in word_list if word not in stop_words]
raw['review'] = raw['review'].apply(remove_stop_words)

# %%
raw = raw.dropna(subset=['review'],how='all')
raw = raw[raw['review'].map(len) > 0]
def avg_word(words):
  return (sum(len(word) for word in words)/len(words))

raw['avg_word'] = raw['review'].apply(lambda x: avg_word(x))
raw['word_count'] = raw['review'].map(len)

# %%
raw
# Out:
#         rating                                             review  avg_word  \
# 0            1  [pengiriman, ninja, berbeda, kurir, internal, ...  6.363636
# 1            1  [pesananku, nomor, order, terkirim, nomor, ord...  6.685714
# 2            5  [sia, sia, susah, payah, ikutan, flashsale, ha...  6.000000
# 3            5  [kali, gagal, flashsale, nga, nyangka, estimas...  6.214286
# 4            5  [setuju, flash sale, sih, strategi, marketing,...  6.863636
# 5            1  [kurir, ninja, expres, lambat, kecewa, sih, la...  5.222222
# 6            1  [pengiriman, kota, depok, membutuhkan, terhitu...  7.033333
# 7            5  [barang, lebih baik, pakai, ekspedisi, diperca...  5.909091
# 8            5  [saran, tolong, pengitiman, paket, jng, melalu...  5.750000
# 9            5  [telepon genggam, xiaomi, oke, cepat, kurir, r...  5.800000
# 10           1  [beli, flash, sale, xiaomi, redmi, a, powerban...  5.500000
# 11           1  [barangnya, cepat, sayang, pesan, hitam, hitam...  6.375000
# 12           5  [proses, pengiriman, pemesanan, cepat, xiaomi,...  5.444444
# 13           1  [barang, bagus, garansi, tam, dikirim, jam, ma...  5.333333
# 14           5  [dpet, redmi, plus, emas, hitam, skrng, pagi, ...  4.500000
# 15           1  [lazada, kadangh, pengirimanya, kadang, cepat,...  6.181818
# 16           4  [kali, flash, sale, barang, aman, packing, rap...  5.666667
# 17           5  [pengiriman, cepat, kurir, ramah, lazada, top,...  6.076923
# 18           5  [bismilah, walkhamdulilah, barang, diterima, k...  7.555556
# 19           5  [flash, sale, terbaik, pesan, kemarin, langsun...  6.636364
# 20           5  [mohon, kali, depanya, bergantung, agen, kurir...  7.285714
# 21           4  [mingu, mas, kurir, nganterin, barang, thank, ...  5.809524
# 22           5  [flash, sale, buah, diac, buah, disayangkan, s...  6.882353
# 23           5  [kurirnya, maf, tugasnya, mengantarkan, barang...  7.083333
# 24           5  [jualnya, seharga, bundling, hands, fre, trnya...  6.600000
# 25           3  [bingung, balikin, dana, vocher, balikin, dana...  5.416667
# 26           4  [unit, telepon genggam, xiomie, redmi, a, bata...  6.333333
# 27           5  [terimakasih, berkat, lazada, menabung, pengha...  7.642857
# 28           1  [kesekian, kali, flash, sale, alhamdulilah, ba...  7.000000
# 29           1  [barang, aman, sistem, cash on delivery, butuh...  7.117647
# ...        ...                                                ...       ...
# 280751       1  [packing, alakadarnya, barang, kualitas, stand...  7.444444
# 280752       1                [kualitas, barang, sesuai, harapan]  6.750000
# 280753       3  [barang, packing, rapi, bhan, lumayan, dngan, ...  5.250000
# 280757       2                                [puas, produk, nya]  4.333333
# 280760       3  [dompetnya, oke, and, murah, thank, s, lazada,...  4.625000
# 280762       3  [bagus, harga, segitu, posisi, kartu, beda, ga...  5.285714
# 280764       1                                     [bagus, sesua]  5.000000
# 280765       1  [barang, bagus, sesuai, harga, tolong, kuati, ...  6.375000
# 280766       3                     [bagus, suka, kurirnya, sopan]  5.500000
# 280767       3                                 [sesuailah, harga]  7.000000
# 280770       3  [kebanyakan, dompet, type, cewek, bkan, cowo, ...  6.000000
# 280771       1                                   [recomen, cepat]  6.000000
# 280773       2  [real, pict, barang, bagus, kiriman, sesuai, e...  6.375000
# 280776       3      [bagus, cardholder, nya, beda, gambar, bagus]  5.500000
# 280777       3                [barang, sesuai, deskripsi, produk]  6.750000
# 280778       2                                    [puas, pokonya]  5.500000
# 280779       2  [sesuai, gambar, bahanya, bagus, harga, nya, s...  5.833333
# 280780       2  [bagus, halus, sesuai, gambar, bagus, garuda, ...  6.111111
# 280781       1                 [barang, diterima, ongkirnya, nya]  6.500000
# 280782       3  [kualitas, barang, terima, bagus, dipakai, men...  6.461538
# 280783       3    [barang, nya, bagus, jelek, jahitan, nya, rapi]  4.714286
# 280784       3                    [sesuai, pesanan, terima kasih]  8.333333
# 280786       3  [nya, cepat, buanget, rekomendasi, seler, suks...  6.142857
# 280787       3  [bagus, jahitan, rapi, kalok, cowok, kebesaren...  5.900000
# 280791       1                                            [bagus]  5.000000
# 280793       3  [sesuai, gambar, beda, barang, kirim, gambar, ...  5.076923
# 280797       2                 [dompet, nya, tebel, sesuai, foto]  4.800000
# 280798       3               [barang, terima, bagus, txs, lazada]  5.200000
# 280800       3           [barangy, lumayan, bagus, sesuai, harga]  6.000000
# 280801       3   [lumayan, sesuai, gambar, packing, rapi, jempol]  6.000000
#
#         word_count
# 0               11
# 1               35
# 2               18
# 3               14
# 4               22
# 5                9
# 6               60
# 7               11
# 8               12
# 9               15
# 10              12
# 11               8
# 12              18
# 13              15
# 14              12
# 15              11
# 16              12
# 17              13
# 18               9
# 19              11
# 20              14
# 21              21
# 22              17
# 23              12
# 24              10
# 25              12
# 26              18
# 27              14
# 28              10
# 29              34
# ...            ...
# 280751           9
# 280752           4
# 280753           8
# 280757           3
# 280760           8
# 280762           7
# 280764           2
# 280765           8
# 280766           4
# 280767           2
# 280770           9
# 280771           2
# 280773           8
# 280776           6
# 280777           4
# 280778           2
# 280779          12
# 280780           9
# 280781           4
# 280782          13
# 280783           7
# 280784           3
# 280786           7
# 280787          10
# 280791           1
# 280793          13
# 280797           5
# 280798           5
# 280800           5
# 280801           6
#
# [19855 rows x 4 columns]
